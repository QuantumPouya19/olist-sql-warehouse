# %%
import sys
sys.path.insert(0, "..")
from src.db import query
import pandas as pd
pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 200)

# %%
# Cell 2 — Q01
df = query("q01_monthly_revenue.sql")
print(df.to_string(index=False))
# Out:
#      month  n_orders    revenue  prev_month_revenue  mom_growth_pct
# 2016-09-01         1     143.46                 NaN             NaN
# 2016-10-01       265   46490.66              143.46    32306.705702
# 2016-12-01         1      19.62            46490.66      -99.957798
# 2017-01-01       750  127482.37               19.62   649657.237513
# 2017-02-01      1653  271239.32           127482.37      112.766142
# 2017-03-01      2546  414330.95           271239.32       52.754752
# 2017-04-01      2303  390812.40           414330.95       -5.676272
# 2017-05-01      3546  566851.40           390812.40       45.044374
# 2017-06-01      3135  490050.37           566851.40      -13.548706
# 2017-07-01      3872  566299.08           490050.37       15.559362
# 2017-08-01      4193  645832.36           566299.08       14.044395
# 2017-09-01      4150  701077.49           645832.36        8.554098
# 2017-10-01      4478  751117.01           701077.49        7.137516
# ...

# %%
# Cell 3 — Q02
df = query("q02_top_categories.sql")
print(df.to_string(index=False))
# Out:
#              category  revenue_2017  revenue_2018  yoy_growth_pct
#        bed_bath_table     580949.20     643653.48       10.793419
#         health_beauty     540949.44     866810.34       60.238698
#         watches_gifts     511800.97     749738.44       46.490234
#        sports_leisure     511372.28     604393.87       18.190581
# computers_accessories     447872.56     583989.37       30.391862
#            cool_stuff     430284.20     260159.81      -39.537680
#       furniture_decor     403406.19     470024.38       16.513924
#                  toys     345717.73     196751.80      -43.088889
#          garden_tools     310222.32     255458.17      -17.653195
#            housewares     275188.71     481661.00       75.029346
#                  auto     269098.28     399005.20       48.274898
#             perfumery     237888.24     199968.19      -15.940279
#                  baby     173472.02     291738.08       68.175871
# ...

# %%
# Cell 4 — Q03
df = query("q03_delivery_performance.sql")
print(df.to_string(index=False))
# Out:
# state  n_orders  pct_early  pct_on_time  pct_late  avg_days_to_deliver
#    MA       799  79.724656     2.252816 18.022528            21.588235
#    CE      1427  84.723196     1.681850 13.594954            20.913805
#    PI       523  84.512428     1.912046 13.575526            19.317400
#    BA      3685  86.322931     1.791045 11.886024            19.187246
#    RJ     14146  87.028135     1.350205 11.621660            15.073519
#    PA      1054  87.571157     1.138520 11.290323            23.702087
#    ES      2226  87.780773     1.482480 10.736748            15.594340
#    PB       588  88.775510     0.510204 10.714286            20.534014
#    PE      1747  89.868346     1.087579  9.044076            18.178592
#    RN       521  89.635317     1.343570  9.021113            19.272553
#    MS       812  89.162562     1.847291  8.990148            15.449507
#    SC      4097  90.383207     1.440078  8.176715            14.941665
# ...

# %%
# Cell 5 — Q04
df = query("q04_review_score_trend.sql")
print(df.to_string(index=False))
# Out:
#        day  n_reviews  avg_score  rolling_30d_avg
# 2016-09-04          1   1.000000         1.000000
# 2016-09-05          1   1.000000         1.000000
# 2016-09-13          1   1.000000         1.000000
# 2016-09-15          1   1.000000         1.000000
# 2016-10-02          1   1.000000         1.000000
# 2016-10-03          8   3.000000         1.333333
# 2016-10-04         63   3.634921         1.662132
# 2016-10-05         45   3.222222         1.857143
# 2016-10-06         51   3.450980         2.034236
# 2016-10-07         44   3.568182         2.187631
# 2016-10-08         42   3.952381         2.348062
# 2016-10-09         26   3.615385         2.453673
# 2016-10-10         38   3.763158         2.554402
# 2016-10-22          1   1.000000         2.443373
# 2016-12-23          1   5.000000         2.613815
# 2017-01-05         32   4.906250         2.757092
# 2017-01-06          4   4.750000         2.874322
# 2017-01-07          4   3.000000         2.881304
# ...

# %%
# Cell 6 — Q05
df = query("q05_repeat_customer_cohorts.sql")
print(df.to_string(index=False))
# Out:
# cohort_month  cohort_size  repeat_in_90d  repeat_in_180d  repeat_ever  pct_repeat_ever
#   2017-01-01          752            7.0            12.0         35.0         4.654255
#   2017-02-01         1690           16.0            27.0         55.0         3.254438
#   2017-03-01         2571           27.0            47.0         98.0         3.811746
#   2017-04-01         2325           27.0            43.0         87.0         3.741935
#   2017-05-01         3541           52.0            80.0        147.0         4.151370
#   2017-06-01         3102           37.0            66.0        124.0         3.997421
#   2017-07-01         3822           47.0            71.0        131.0         3.427525
#   2017-08-01         4130           55.0            96.0        144.0         3.486683
#   2017-09-01         4075           70.0           105.0        146.0         3.582822
#   2017-10-01         4392           54.0            74.0        121.0         2.755009
# ...

# %%
# Cell 7 — Q06
df = query("q06_seller_concentration.sql")
print(df.to_string(index=False))
# Out:
#  rank  pct_sellers  seller_revenue  pct_cumulative_revenue
#     1     0.032310       249640.70                1.575661
#     5     0.161551       204084.73                7.350993
#    10     0.323102       160602.68               12.804682
#    25     0.807754        70680.95               23.219974
#    50     1.615509        50142.83               32.243412
#   100     3.231018        29887.47               44.373734
#   200     6.462036        15640.21               57.385114
#   250     8.077544        13639.41               61.996775
#   300     9.693053        11912.62               66.022422
#   400    12.924071         8801.84               72.421763
#   500    16.155089         7180.28               77.426550
#   600    19.386107         5608.54               81.399959
#   700    22.617124         4557.50               84.578309
#   800    25.848142         3757.78               87.207911
#   900    29.079160         3023.31               89.323856
# ...

# %%
# Cell 8 — Q07
df = query("q07_payment_method_mix.sql")
print(df.to_string(index=False))
# Out:
# order_size_tier  n_orders  pct_credit_card  pct_boleto  pct_voucher  pct_debit_card  avg_order_value
#     01_under_50     16352        69.850783   23.868640     4.121820        2.158757        36.870591
#    02_50_to_100     29382        73.745831   21.234089     3.406848        1.613233        73.298466
#   03_100_to_250     37472        77.794086   18.379056     2.465841        1.361016       155.772411
#   04_250_to_500      9150        80.546448   16.469945     1.814208        1.169399       337.464651
#     05_500_plus      4121        81.315215   15.894200     1.795681        0.994904       924.747586

# %%
# Cell 9 — Q08
df = query("q08_geographic_revenue.sql")
print(df.to_string(index=False))
# Out:
# state                  city  n_orders    revenue  rank_in_state  rank_overall
#    SP             sao paulo     15029 2106172.62              1             1
#    RJ        rio de janeiro      6594 1110385.11              1             2
#    MG        belo horizonte      2702  406538.22              1             3
#    DF              brasilia      2074  344829.31              1             4
#    PR              curitiba      1490  238699.38              1             5
#    RS          porto alegre      1342  214805.84              1             6
#    SP              campinas      1408  209270.93              2             7
#    BA              salvador      1188  207617.45              1             8
#    SP             guarulhos      1143  157632.99              3             9
#    RJ               niteroi       824  135297.24              2            10
#    SP sao bernardo do campo       911  116784.58              4            11
# ...

# %%
# Cell 10 — Q09
df = query("q09_basket_size_distribution.sql")
print(df.to_string(index=False))
# Out:
# basket_bucket  n_orders  pct_orders  total_revenue  pct_revenue  avg_order_value
#        1 item     86843   90.013267    13028990.34    84.495341       150.029252
#       2 items      7392    7.661850     1559217.80    10.111807       210.933144
#       3 items      1306    1.353676      381694.90     2.475360       292.262557
#     4-5 items       688    0.713116      283111.02     1.836026       411.498576
#      6+ items       249    0.258090      166759.69     1.081467       669.717631

# %%
# Cell 11 — Q10
df = query("q10_churn_funnel.sql")
print(df.to_string(index=False))
# Out:
#  cohort_size  returned_30d  returned_60d  returned_90d  returned_180d  returned_ever  pct_30d  pct_90d  pct_ever
#        13981          94.0         140.0         189.0          292.0          546.0 0.672341 1.351835    3.9053
